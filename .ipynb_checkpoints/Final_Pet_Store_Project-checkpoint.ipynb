# %%
# Imports All relevant libraries
import requests
import json 
import pandas as pd
import csv
import os
from super_func import *

# %%
# opens the file to the api keys saved as creds
with open('.hidden/creds.json') as f:
    creds = json.load(f)

# %%
# Sets variables for url_params
term = 'Pet Store'
location = 'Manhatten'
limit = 50
offset = 0
# Sets variables for csv file names for business
csv_filename = 'petstores.csv'
csv_filepath = './petstores.csv'
# Sets variables for csv file names for reviews
reviews_filename = 'reviews.csv'

# %%
# Url argument
url_params = {'term': term,
        'location': location,
        'limit': limit,
        'offset': offset}

# %%
# Deletes the current csv file 
if os.path.isfile(csv_filename):
    os.remove(csv_filename)
# Deletes the current csv file 
if os.path.isfile(csv_filename):
    os.remove(csv_filename)

# %%
# create a variable  to keep track of which result you are in. 
cur = 0
num = 50
#set up a while loop to go through and grab the result 
while cur < num and cur < 1000:
    #set the offset parameter to be where you currently are in the results 
    url_params['offset'] = cur
    #make your API call with the new offset number
    results = yelp_call(url_params, creds)
    
    #after you get your results you can now use your function to parse those results
    parsed_results = parse_results(results)
    
    # use your function to insert your parsed results into the db
    df_save(parsed_results, str(csv_filename))
    #increment the counter by 50 to move on to the next results
    cur += 50

# %%
# Lets you store the csv in a pandas DF
pet_stores = pd.read_csv('petstores.csv', index_col=0)

# %%
# Deletes the current csv file 
if os.path.isfile(reviews_filename):
    os.remove(reviews_filename)

# %%
business_ids, business_ids_names, business_names = business_ids_get()

# %%
reviews = yelp_call_reviews(creds, business_ids)

# %%
list_of_reviews = list_of_reviews(reviews,business_ids, business_ids_names, business_names)

# %%
reviews_df = pd.DataFrame(list_of_reviews)
reviews_selection = reviews_df[['business_id', 'text_excerpt', 'review_url',  'time_created', 'user_name']]
reviews_cleaned = reviews_selection.rename(columns={"business_id": "id"})

# %%
df_save(reviews_cleaned, reviews_filename)

# %%
pet_stores_csv = pd.read_csv('petstores.csv', index_col= 0)
reviews_csv = pd.read_csv('reviews.csv', index_col= 0)

# %%
merged_result = pd.merge(pet_stores_csv, reviews_csv, on="id")

# %%
merged_result
# Out:
#                          id                name  reviews  rating    zip  \
# 0    ymyU-LwOrIs3M0K3_YJr1g               Petco       62     3.5  10022
# 1    ymyU-LwOrIs3M0K3_YJr1g               Petco       62     3.5  10022
# 2    ymyU-LwOrIs3M0K3_YJr1g               Petco       62     3.5  10022
# 3    RpOtosl5m46soAAb4PFM1A       Spoiled Brats       57     4.5  10019
# 4    RpOtosl5m46soAAb4PFM1A       Spoiled Brats       57     4.5  10019
# ..                      ...                 ...      ...     ...    ...
# 145  tYZEFqmbGEA0cN6SGz7Swg          Petropolis       83     4.5  10006
# 146  tYZEFqmbGEA0cN6SGz7Swg          Petropolis       83     4.5  10006
# 147  sW7uy7GuGPjoZxh5HISovA  Greenland Pet Shop       15     4.5  10023
# 148  sW7uy7GuGPjoZxh5HISovA  Greenland Pet Shop       15     4.5  10023
# 149  sW7uy7GuGPjoZxh5HISovA  Greenland Pet Shop       15     4.5  10023
#
#       latitude  longitude     alias  \
# 0    40.756400 -73.967735  petstore
# 1    40.756400 -73.967735  petstore
# 2    40.756400 -73.967735  petstore
# 3    40.762321 -73.988716  petstore
# 4    40.762321 -73.988716  petstore
# ..         ...        ...       ...
# 145  40.707825 -74.014490  petstore
# 146  40.707825 -74.014490  petstore
# 147  40.772972 -73.989675  petstore
# 148  40.772972 -73.989675  petstore
# 149  40.772972 -73.989675  petstore
#
#                                           text_excerpt  \
# 0    Annie the groomer is absolutely the best. I wa...
# 1    I order the dog dry food from petco two day be...
# 2    Let me start by saying I have had fish and kno...
# 3    Stocked with everything you need & the employe...
# 4    Huge selection and good brands here. Staff rea...
# ..                                                 ...
# 145  Love this place, our 2 pups love it too.\n\nWh...
# 146  Very small store with very limited selection. ...
# 147  Brought my mini schnauzer here on The recommen...
# 148  Worst worst pet shop ever. They made a huge as...
# 149  Hani and wife very helpful- both on hand, i wi...
#
#                                             review_url         time_created  \
# 0    https://www.yelp.com/biz/petco-new-york-13?adj...  2018-06-07 10:12:49
# 1    https://www.yelp.com/biz/petco-new-york-13?adj...  2020-12-22 16:16:09
# 2    https://www.yelp.com/biz/petco-new-york-13?adj...  2020-10-22 19:01:33
# 3    https://www.yelp.com/biz/spoiled-brats-new-yor...  2021-04-29 07:04:09
# 4    https://www.yelp.com/biz/spoiled-brats-new-yor...  2019-11-10 14:41:13
# ..                                                 ...                  ...
# 145  https://www.yelp.com/biz/petropolis-new-york?a...  2019-10-05 12:53:07
# 146  https://www.yelp.com/biz/petropolis-new-york?a...  2019-12-15 17:20:22
# 147  https://www.yelp.com/biz/greenland-pet-shop-ne...  2020-11-20 13:04:51
# 148  https://www.yelp.com/biz/greenland-pet-shop-ne...  2019-06-11 14:49:14
# 149  https://www.yelp.com/biz/greenland-pet-shop-ne...  2019-11-22 16:34:31
#
#           user_name
# 0          Megan H.
# 1          Sally Z.
# 2       Jennifer M.
# 3           Yani A.
# 4          Zijun H.
# ..              ...
# 145      Phillip S.
# 146  Konstantine K.
# 147        Laura Y.
# 148      Ju Hyun L.
# 149      Meldrin L.
#
# [150 rows x 12 columns]
